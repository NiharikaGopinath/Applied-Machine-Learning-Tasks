# %%
#Dependencies
import pandas as pd
import gensim #the library for Topic modelling
from gensim.models.ldamulticore import LdaMulticore
from gensim import corpora, models
import pyLDAvis.gensim #LDA visualization library

from nltk.corpus import stopwords
import string
from nltk.stem.wordnet import WordNetLemmatizer

import warnings
warnings.simplefilter('ignore')
from itertools import chain

# %%
df = pd.read_pickle('news_topic_modelling_0.pkl')
print(df.shape)
df
# Out:
# (10, 2)
#     topic                                               text
# 0  corona  \n E-commerce companies can deliver essential ...
# 1  corona  \nGoa Chief Minister Pramod Sawant on Sunday s...
# 2  corona  \n Tamil Nadu has extended the coronavirus loc...
# 3  corona  \nSports complexes and stadia were on Sunday p...
# 4  corona  \nMaharashtra on Sunday reported 2,347 coronav...
# 5  iphone  \nThe news comes from Front Page Tech’s Jon Pr...
# 6  iphone  \nYou can count on death, taxes, and a steady ...
# 7  iphone  \nApple had been hoping to move past its recen...
# 8  iphone  \nThe iPhone 12 is supposed to deliver a small...
# 9  iphone  \nThanks to a flurry of exciting leaks, Apple’...

# %%
#clean the data
stop = set(stopwords.words('english'))
exclude = set(string.punctuation)
lemma = WordNetLemmatizer()

def clean(text):
    stop_free = ' '.join([word for word in text.lower().split() if word not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = ' '.join([lemma.lemmatize(word) for word in punc_free.split()])
    return normalized.split()

# %%
df['text_clean']=df['text'].apply(clean)

# %%
#create dictionary
dictionary = corpora.Dictionary(df['text_clean'])
#Total number of non-zeroes in the BOW matrix (sum of the number of unique words per document over the entire corpus).
print(dictionary.num_nnz)
# Out:
# 2130

# %%
#create document term matrix
doc_term_matrix = [dictionary.doc2bow(doc) for doc in df['text_clean'] ]
print(len(doc_term_matrix))
# Out:
# 10

# %%
lda = gensim.models.ldamodel.LdaModel

# %%
num_topics=6
# %time ldamodel = lda(doc_term_matrix,num_topics=num_topics,id2word=dictionary,passes=50,minimum_probability=0)
# Out:
# Wall time: 680 ms

# %%
ldamodel.print_topics(num_topics=num_topics)
# Out:
# [(0,
#   '0.023*"zone" + 0.014*"allowed" + 0.014*"lockdown" + 0.010*"containment" + 0.010*"essential" + 0.007*"activity" + 0.007*"allow" + 0.007*"centre" + 0.007*"deliver" + 0.007*"phase"'),
#  (1,
#   '0.023*"said" + 0.015*"state" + 0.013*"covid19" + 0.013*"train" + 0.010*"passenger" + 0.010*"positive" + 0.010*"express" + 0.008*"patient" + 0.008*"people" + 0.008*"take"'),
#  (2,
#   '0.057*"iphone" + 0.028*"apple" + 0.017*"12" + 0.012*"new" + 0.010*"would" + 0.009*"prosser" + 0.009*"charging" + 0.009*"portless" + 0.008*"11" + 0.008*"model"'),
#  (3,
#   '0.019*"ipad" + 0.014*"tap" + 0.012*"app" + 0.011*"apple" + 0.011*"click" + 0.010*"use" + 0.010*"device" + 0.009*"screen" + 0.009*"free" + 0.008*"like"'),
#  (4,
#   '0.014*"io" + 0.013*"security" + 0.011*"user" + 0.010*"case" + 0.010*"exploit" + 0.010*"state" + 0.008*"new" + 0.007*"apple" + 0.007*"lockdown" + 0.006*"reported"'),
#  (5,
#   '0.014*"sport" + 0.009*"resumption" + 0.007*"sunday" + 0.007*"india" + 0.007*"athlete" + 0.007*"camp" + 0.007*"least" + 0.007*"lockdown" + 0.007*"complex" + 0.005*"one"')]

# %%
lda_display = pyLDAvis.gensim.prepare(ldamodel, doc_term_matrix, dictionary, sort_topics=False, mds='mmds')
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1179224426700548648392503405"></div>
# <script type="text/javascript">
#
# var ldavis_el1179224426700548648392503405_data = {"mdsDat": {"x": [0.04038607842182139, -0.016821996304471454, -0.20939103105582757, -0.07249337921215264, 0.15446044758798638, 0.10385988056264384], "y": [0.05389077592670242, -0.09042361666381199, -0.050811408590761775, 0.1957737168818825, -0.11385107674564517, 0.0054216091916340185], "topics": [1, 2, 3, 4, 5, 6], "cluster": [1, 1, 1, 1, 1, 1], "Freq": [5.803383156787546, 4.880594350114972, 35.27117270556191, 21.45996529893307, 26.53547513535104, 6.049409353251463]}, "tinfo": {"Term": ["iphone", "said", "ipad", "state", "zone", "lockdown", "tap", "allowed", "12", "io", "app", "security", "click", "apple", "exploit", "sport", "covid19", "essential", "prosser", "charging", "case", "deliver", "free", "containment", "sunday", "centre", "people", "portless", "train", "screen", "ecommerce", "green", "third", "nonessential", "except", "salon", "orange", "item", "movement", "phase", "zone", "activity", "red", "strictly", "boost", "buffer", "retain", "monitored", "thereby", "march", "colourcode", "incidence", "emergency", "includes", "daytime", "public", "prohibited", "restricted", "cannot", "televised", "containment", "essential", "mall", "platform", "allowed", "open", "lockdown", "allow", "centre", "deliver", "good", "people", "order", "announced", "sunday", "said", "state", "however", "company", "train", "passenger", "express", "positive", "rajdhani", "railway", "arrived", "madgao", "tested", "goa", "sawant", "delhi", "nizamuddin", "halt", "covid19", "patient", "280", "mingle", "ruled", "there", "include", "entry", "transmission", "enter", "wherein", "postponing", "arriving", "board", "truck", "stop", "station", "chief", "class", "said", "18", "people", "take", "state", "minister", "sunday", "far", "also", "case", "saturday", "iphone", "prosser", "charging", "portless", "model", "port", "pro", "wireless", "usbc", "2021", "connector", "explains", "sensor", "12", "lightning", "lineup", "could", "11", "sense", "plus", "plan", "future", "say", "5g", "presumably", "se", "range", "update", "leak", "given", "would", "apple", "smart", "upgrade", "phone", "new", "display", "design", "make", "also", "may", "company", "apple\u2019s", "said", "tap", "click", "free", "apps", "ipad", "streaming", "tv", "tablet", "app", "dashcam", "you\u2019re", "available", "control", "show", "kim", "eye", "turn", "stream", "ipads", "content", "store", "access", "check", "ebooks", "setting", "radio", "on", "airplay", "screen", "old", "use", "keep", "call", "music", "device", "like", "video", "make", "set", "apple", "phone", "new", "one", "time", "exploit", "reported", "district", "zerodium", "chennai", "nadu", "tamil", "run", "three", "vulnerability", "io", "security", "coronavirus", "cent", "crossed", "100", "carry", "total", "per", "firm", "researcher", "flaw", "issue", "release", "government", "taxi", "le", "industrial", "exempted", "factory", "restriction", "user", "case", "including", "day", "order", "lockdown", "state", "extended", "news", "travel", "allowed", "death", "centre", "new", "time", "around", "may", "apple", "said", "sport", "resumption", "least", "camp", "complex", "declared", "indian", "spectator", "batra", "training", "rijiju", "stadium", "demanding", "olympic", "india", "athlete", "unlikely", "congregation", "kiren", "sponsor", "onetime", "3000", "matter", "among", "governing", "clearing", "possibly", "authority", "crore", "220", "ministry", "guideline", "open", "sunday", "end", "permitted", "lockdown", "week", "due", "one", "allowed", "also", "may", "even"], "Freq": [66.0, 14.0, 14.0, 16.0, 7.0, 10.0, 10.0, 9.0, 21.0, 13.0, 9.0, 12.0, 7.0, 46.0, 9.0, 3.0, 3.0, 4.0, 11.0, 11.0, 12.0, 5.0, 6.0, 3.0, 5.0, 5.0, 4.0, 10.0, 2.0, 7.0, 1.3718602084158862, 1.3718600327051333, 1.3718600327051333, 1.3718600327051333, 1.3718600327051333, 1.3718600327051333, 1.371859944849757, 0.9386315542603577, 0.9386315542603577, 1.3718718931809428, 4.404607857404622, 1.3719140637615985, 0.9386390219673488, 0.505400000 ...

# %%
lda_corpus = ldamodel[doc_term_matrix]

# %%
[doc for doc in lda_corpus]
# Out:
# [[(0, 0.0018115373), (1, 0.9963859), (2, 0.001802596)],
#  [(0, 0.0021795002), (1, 0.9956781), (2, 0.0021424019)],
#  [(0, 0.0011576689), (1, 0.9976922), (2, 0.0011501585)],
#  [(0, 0.7642158), (1, 0.23400915), (2, 0.0017750324)],
#  [(0, 0.002390022), (1, 0.9952377), (2, 0.0023722842)],
#  [(0, 0.9979932), (1, 0.0009908855), (2, 0.0010159459)],
#  [(0, 0.000509617), (1, 0.00049094344), (2, 0.9989994)],
#  [(0, 0.0008239481), (1, 0.0008222271), (2, 0.99835384)],
#  [(0, 0.9977142), (1, 0.0011179815), (2, 0.0011677437)],
#  [(0, 0.99860674), (1, 0.00069160707), (2, 0.00070163823)]]

# %%
scores = list(chain(*[[score for topic_id,score in topic] \
                      for topic in [doc for doc in lda_corpus]]))

threshold = sum(scores)/len(scores)
print(threshold)
# Out:
# 0.33333333491464145

# %%
cluster1 = [j for i,j in zip(lda_corpus,df.index) if i[0][1] > threshold]
cluster2 = [j for i,j in zip(lda_corpus,df.index) if i[1][1] > threshold]
cluster3 = [j for i,j in zip(lda_corpus,df.index) if i[2][1] > threshold]
# cluster4 = [j for i,j in zip(lda_corpus,df.index) if i[3][1] > threshold]
# cluster5 = [j for i,j in zip(lda_corpus,df.index) if i[4][1] > threshold]

print(len(cluster1))
print(len(cluster2))
print(len(cluster3))
# print(len(cluster4))
# print(len(cluster5))
# Out:
# 4
# 4
# 2
